# %%
import networkx as nx

# %%
G=nx.Graph()

# %%
G.add_edges_from([(1,2),(2,3),(3,4)])

# %%
dict(G.degree())
# Out:
# {1: 1, 2: 2, 3: 2, 4: 1}

# %%
nx.to_numpy_matrix(G)
# Out:
# matrix([[0., 1., 0., 0.],
#         [1., 0., 1., 0.],
#         [0., 1., 0., 1.],
#         [0., 0., 1., 0.]])

# %%
f=nx.read_edgelist('graph.txt',nodetype=str,create_using=nx.DiGraph())
nx.draw(f,with_labels=True,node_size=1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 f=nx.read_edgelist('graph.txt',nodetype=str,create_using=nx.DiGraph())
#       2 nx.draw(f,with_labels=True,node_size=1000)
#
# File ~\miniconda3\lib\site-packages\networkx\utils\decorators.py:816, in argmap.__call__.<locals>.func(_argmap__wrapper, *args, **kwargs)
#     815 def func(*args, __wrapper=None, **kwargs):
# --> 816     return argmap._lazy_compile(__wrapper)(*args, **kwargs)
#
# File <class 'networkx.utils.decorators.argmap'> compilation 5:3, in argmap_read_edgelist_1(path, comments, delimiter, create_using, nodetype, data, edgetype, encoding)
#       1 from collections import defaultdict
#       2 from os.path import splitext
# ----> 3 from contextlib import contextmanager
#       4 from pathlib import Path
#       6 import networkx as nx
#
# ...

# %%
#___________________________________________________________________

# %%
#___________________________________________________________________

# %%
import pandas as pd

# %%
df=pd.read_csv('HomoSapiens_binary_hq.txt',nrows=100,sep='\t',usecols=['Gene_A','Gene_B','Gene_B'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7684/77175337.py in <module>
# ----> 1 df=pd.read_csv('HomoSapiens_binary_hq.txt',nrows=100,sep='\t',usecols=['Gene_A','Gene_B','Gene_B'])
#
# NameError: name 'pd' is not defined

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7684/1396537375.py in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
bio_graph=nx.from_pandas_edgelist(df,'Gene_A','Gene_B',create_using=nx.DiGraph())

# %%
nx.draw(bio_graph,with_labels=True)

# %%
import pandas as pd

# %%
df=pd.read_csv('SaccharomycesCerevisiaeS288C_binary_hq.txt',nrows=100,sep='\t',usecols=['Uniprot_A','Uniprot_B'])
df
# Out:
#      Uniprot_A   Uniprot_B
# 0   A0A023PYF7      P39743
# 1   A0A250W8A7  A0A250W8A7
# 2   A0A250WL92  A0A250WL92
# 3       A2P2R3      P04821
# 4       A2P2R3      P38753
# ..         ...         ...
# 95      O13558      P15274
# 96      O13558      P32366
# 97      O13558      Q12346
# 98      O13559      P40029
# 99      O13559      Q03407
#
# [100 rows x 2 columns]

# %%
bio_graph=nx.from_pandas_edgelist(df,'Uniprot_B','Uniprot_A',create_using=nx.DiGraph())
nx.draw(bio_graph,with_labels=True)
