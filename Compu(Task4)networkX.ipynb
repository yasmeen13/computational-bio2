# %%
import networkx as nx

# %%
G =nx.Graph()

# %%
G.add_nodes_from(['a','b','c','d'])

# %%
G.add_edges_from([('a','b'),('a','c'),('c','d'),('b','d')])

# %%
nx.draw(G,with_labels=True,node_color='blue',node_size=2000,font_size=30,font_color='white')
